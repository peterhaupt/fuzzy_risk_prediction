# %%
import pandas as pd

# Load the train and test DataFrames
train_df = pd.read_pickle("data/train.pkl")
test_df = pd.read_pickle("data/test.pkl")

# Display the first few rows of the DataFrames
print("Train DataFrame:")
display(train_df.head())

print("Test DataFrame:")
display(test_df.head())

# Check correlations for numerical columns in the train DataFrame
print("\nCorrelation Matrix (Train DataFrame):")
train_corr = train_df.select_dtypes(include=['int64', 'float64']).corr()
display(train_corr)

# Check correlations for numerical columns in the test DataFrame
print("\nCorrelation Matrix (Test DataFrame):")
test_corr = test_df.select_dtypes(include=['int64', 'float64']).corr()
display(test_corr)

# Save the correlation matrices as CSV files (optional)
train_corr.to_csv("data/train_correlations.csv")
test_corr.to_csv("data/test_correlations.csv")
# Out:
# Train DataFrame:
#     eid         p31  p34     p46_i0    p47_i0     p48_i0     p49_i0  \
# 0  ID_1  Category_D   25  21.842481  0.273070  25.788324  89.306982
# 1  ID_2  Category_B   33  78.360127  1.135750  44.142222  75.653100
# 2  ID_3  Category_A    9  31.253445  0.075037   0.942622  51.298032
# 3  ID_4  Category_C   79  21.156981  0.543026  40.886846  93.378278
# 4  ID_5  Category_E   71  52.183513  0.067884  98.016506   7.419030
#
#       p50_i0     p51_i0         p52  ...  p30870_i0  p30880_i0  p30890_i0  \
# 0  39.826116  21.864889  Category_A  ...  66.626955  96.821467  76.055925
# 1  83.771701  91.961506  Category_E  ...  79.581666  81.403491  42.618508
# 2  52.549592  82.403842  Category_D  ...  61.203799  47.812377  78.975174
# 3   3.891030  76.442123  Category_D  ...  50.618399  23.009571   7.182506
# 4  14.083252  28.613473  Category_B  ...   7.174542  30.662797  55.812202
#
#    p30897_i0  p30900_i0    p130894     p130895  birth_date  age_at_baseline  \
# ...
